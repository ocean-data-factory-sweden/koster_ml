# %% [markdown]
# # Koster Machine Learning
#
# The following scripts guide you to create and train a YOLOv3 model for the Koster seafloor observatory project.

# %% [markdown]
# ## Prepare the aggregated data

# %%
# Specify the path for the db
db_path = "/data/database/demo.db"

output_folder = "/data/input"
movies_path = "/uploads"
percentage_test = 0.2

data_path_file = "data/koster.data"
names_file = "data/koster.names"
init_weights = "yolov3-spp-ultralytics.pt"
last_weights = "/data/weights/best.pt"
config_file = "cfg/yolov3-spp-1cls.cfg"
bs = 16
epochs = 100
conf_thres = 0.5
class_list = "Deep\ water\ coral"

# %%
# Run the preparation script
# %run -i "../src/prepare_zooniverse.py" -o $output_folder -db $db_path -m $movies_path -pt $percentage_test \
     --class_list $class_list --img_size 720 576
# Out:
#   0%|          | 0/481 [00:00<?, ?it/s]/usr/src/app/koster_ml/src/pims/pims/pyav_reader.py:232: MethodDeprecationWarning: VideoStream.seek is deprecated.
#   self._stream.seek(timestamp + self._first_pts)
# 100%|██████████| 481/481 [04:58<00:00,  1.61it/s]
# Frames extracted successfully
# Processing performance: 5291 frames, 23.98 ms/frame
# Training and test set completed

# %%
# Train YOLO model
# %run -i "../train.py" --data $data_path_file --weights $init_weights --cfg $config_file --batch-size $bs --epochs \
                          $epochs --single-cls
# Out:
# Namespace(accumulate=4, adam=False, arc='default', batch_size=16, bucket='', cache_images=False, cfg='cfg/yolov3-spp-1cls.cfg', data='data/koster.data', device='', epochs=100, evolve=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=True, var=None, weights='yolov3-spp-ultralytics.pt')
# Using CUDA Apex device0 _CudaDeviceProperties(name='GeForce RTX 2080 Ti', total_memory=11019MB)
# Caching labels (1657 found, 0 missing, 0 empty, 0 duplicate, for 1657 images): 100%|██████████| 1657/1657 [00:28<00:00, 59.05it/s]
# Caching labels (2576 found, 0 missing, 0 empty, 0 duplicate, for 2576 images): 100%|██████████| 2576/2576 [00:18<00:00, 142.28it/s]
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Using 8 dataloader workers
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#   0%|          | 0/104 [00:00<?, ?it/s]/usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /opt/conda/lib/python3.6/site-packages/torch/cuda/memory.py:346: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)
#       0/99     4.89G      5.26      2.78         0      8.04        16       416: 100%|██████████| 104/104 [01:56<00:00,  1.12s/it]
#                Class    Images   Targets         P         R   mAP@0.5        F1:   0%|          | 0/81 [00:00<?, ?it/s]/usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/test.py:139: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   ti = (cls == tcls_tensor).nonzero().view(-1)  # prediction indices
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100%|██████████| 81/81 [01:25<00:00,  1.05s/it]
#                  all  2.58e+03  3.61e+03     0.332     0.389      0.26     0.358
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
0.963
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      97/99     6.22G     0.885     0.488         0      1.37        19       416: 100%|██████████| 104/104 [00:35<00:00,  2.92it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
#                  all  2.58e+03  3.61e+03     0.937     0.991     0.991     0.963
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      98/99     6.22G     0.916      0.48         0       1.4        19       416: 100%|██████████| 104/104 [00:39<00:00,  2.66it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100%|██████████| 81/81 [00:27<00:00,  2.97it/s]
#                  all  2.58e+03  3.61e+03     0.938     0.991     0.991     0.964
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      99/99     6.22G     0.893     0.473         0      1.37        21       416: 100%|██████████| 104/104 [00:40<00:00,  2.55it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
#                  all  2.58e+03  3.61e+03     0.939     0.991     0.991     0.964
# 100 epochs completed in 1.951 hours.

# %%
# Evaluate YOLOv3 Model on Unseen Test data for mAP metric
# %run -i "../test.py" --data $data_path_file --weights $last_weights --cfg $config_file --single-cls --conf-thres 0.5
# Out:
# Namespace(batch_size=32, cfg='cfg/yolov3-spp-1cls.cfg', conf_thres=0.5, data='data/koster.data', device='', img_size=416, iou_thres=0.6, save_json=False, single_cls=True, task='test', weights='/data/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2080 Ti', total_memory=11019MB)
#                Class    Images   Targets         P         R   mAP@0.5        F1:   0%|          | 0/81 [00:00<?, ?it/s]/usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
# /usr/src/app/koster_ml/utils/utils.py:935: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(ns, ns, i + 1).imshow(imgs[i].transpose(1, 2, 0))
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100%|██████████| 81/81 [00:52<00:00,  1.55it/s]
#                  all  2.58e+03  3.61e+03     0.979     0.962     0.962      0.97

# %% [markdown]
# ### Visualise model output

# %%
test_image = "/data/input/images/000203\ TMBL-ROV\ 2000\ Säcken\ revet\ EJ\ numrerade\ band_frame_21750.jpg"

# %%
# Evaluate model on other media
# %run -i "../detect.py" --names $names_file --weights $last_weights --cfg $config_file --conf-thres $conf_thres \
                    --source $test_image
# Out:
# Namespace(agnostic_nms=False, cfg='cfg/yolov3-spp-1cls.cfg', classes=None, conf_thres=0.5, device='', fourcc='mp4v', half=False, img_size=416, iou_thres=0.6, names='data/koster.names', output='output', save_txt=False, source='/data/input/images/000203 TMBL-ROV 2000 Säcken revet EJ numrerade band_frame_21750.jpg', view_img=False, weights='/data/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2080 Ti', total_memory=11019MB)
#
# image 1/1 /data/input/images/000203 TMBL-ROV 2000 Säcken revet EJ numrerade band_frame_21750.jpg: 352x416 1 deep_sea_corals, Done. (0.337s)
# Results saved to /usr/src/app/koster_ml/output
# Done. (0.579s)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/usr/src/app/koster_ml/output/000203 TMBL-ROV 2000 Säcken revet EJ numrerade band_frame_21750.jpg")

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(rgb_img)
